# %%
from src.utils.dashboard_loader import DashboardLoader

loader = DashboardLoader()

print(loader.executive_kpis())
print(loader.get_total_policies())
print(loader.get_total_premium())
print(loader.get_total_claims())
print(loader.get_total_profit())
print(loader.get_loss_ratio())
print(loader.get_health_score())
