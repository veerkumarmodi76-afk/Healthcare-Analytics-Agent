# %%
import pandas as pd
df=pd.read_csv("../data/processed/processed_data.csv")

# %%
missing_counts = df.isna().sum()

for col, count in missing_counts.items():
    print(f"{col}: {count}")
# Out:
# ID: 0
# ID_policy: 0
# ID_insured: 0
# period: 0
# date_effect_insured: 0
# date_lapse_insured: 167181
# date_effect_policy: 0
# date_lapse_policy: 174568
# year_effect_insured: 0
# year_lapse_insured: 0
# year_effect_policy: 0
# year_lapse_policy: 0
# exposure_time: 0
# lapse: 0
# seniority_insured: 0
# seniority_policy: 0
# type_policy: 0
# type_policy_dg: 0
# type_product: 0
# reimbursement: 0
# new_business: 0
# distribution_channel: 0
# gender: 0
# age: 0
# premium: 0
# cost_claims_year: 0
# n_medical_services: 0
# n_insured_pc: 0
# n_insured_mun: 0
# n_insured_prov: 0
# IICIMUN: 0
# IICIPROV: 0
# C_H: 0
# C_GI: 0
# C_II: 0
# C_IE_P: 0
# C_IE_S: 0
# C_IE_T: 0
# C_GE_P: 0
# C_GE_S: 0
# C_GE_T: 0
# C_C: 0
# insured_lapsed_flag: 0
# policy_lapsed_flag: 0
# insured_duration: 0
# policy_duration: 0
# family_size: 0
# claim_frequency: 0
# claim_severity: 0
# loss_ratio: 0
# premium_per_exposure: 0
# claims_per_exposure: 0
# age_band: 0
# seniority_band: 0
# lapse_binary: 0
# ...

# %%
df.head()
# Out:
#     ID  ID_policy  ID_insured  period date_effect_insured date_lapse_insured  \
# 0  1_1          1           1    2017          1993-06-15         2017-12-20
# 1  1_2          1           2    2017          1993-06-15                NaN
# 2  2_1          2           1    2017          1993-06-16                NaN
# 3  3_3          3           3    2017          1993-06-15                NaN
# 4  3_5          3           5    2017          1993-06-15                NaN
#
#   date_effect_policy date_lapse_policy  year_effect_insured  \
# 0         1993-06-15               NaN                 1993
# 1         1993-06-15               NaN                 1993
# 2         1993-06-16               NaN                 1993
# 3         1993-06-15               NaN                 1993
# 4         1993-06-15               NaN                 1993
#
#    year_lapse_insured  ...  claim_severity  loss_ratio  premium_per_exposure  \
# ...

# %%
df = pd.read_csv("../data/processed/processed_data.csv")

print(df["risk_class"].isna().sum())
print(df["risk_class_encoded"].isna().sum())
print(df["risk_score"].isna().sum())
# Out:
# 0
# 0
# 0

# %%
print(df["risk_class"].value_counts())
# Out:
# risk_class
# High        57614
# Medium      57178
# Low         57178
# VeryHigh    56741
# Name: count, dtype: int64

# %%
print(df["risk_class_encoded"].value_counts())
# Out:
# risk_class_encoded
# 2    57614
# 1    57178
# 0    57178
# 3    56741
# Name: count, dtype: int64
