# %%
import pandas as pd

df = pd.read_csv("../outputs/underwriting/applicant_risk_scores.csv")
print(df.columns.tolist())
print(df.head())
# Out:
# ['applicant_id', 'risk_score', 'risk_class', 'risk_class_label', 'underwriting_flag', 'shap_top3_drivers']
#    applicant_id  risk_score  risk_class risk_class_label underwriting_flag  \
# 0             1   99.999060           3         VeryHigh           Decline
# 1             2   99.999080           3         VeryHigh           Decline
# 2             1   99.998795           3         VeryHigh           Decline
# 3             3   99.999016           3         VeryHigh           Decline
# 4             5   67.551250           2             High             Rated
#
#     shap_top3_drivers
# 0  see_explain_report
# 1  see_explain_report
# 2  see_explain_report
# 3  see_explain_report
# 4  see_explain_report

# %%
risk_df = pd.read_csv("../outputs/underwriting/applicant_risk_scores.csv")

print(risk_df["applicant_id"].value_counts().head())
# Out:
# applicant_id
# 1    95569
# 2    56169
# 3    31032
# 4    20097
# 5     7535
# Name: count, dtype: int64

# %%
claims_df = pd.read_csv("../outputs/pricing/predicted_claim_cost.csv")

print(claims_df["applicant_id"].value_counts().head())
# Out:
# applicant_id
# 1    95569
# 2    56169
# 3    31032
# 4    20097
# 5     7535
# Name: count, dtype: int64

# %%
pd.read_csv(
    "../outputs/pricing/premium_quotes.csv"
).head()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pd.read_csv(
#       2     "../outputs/pricing/premium_quotes.csv"
#       3 ).head()
#
# File c:\Users\User\Desktop\AI AIP\AIAIP_project\Healthcare-Analytics-Agent\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...
